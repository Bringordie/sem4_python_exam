# %% [markdown]
# # Selenium

# %% [markdown]
# Todo text

# %%
from modules import selenium_twitch

test = selenium_twitch.create_twitch_clip("summit1g", "test", "test")
# Out:
# Username was found
# ...

# %%
count = 1
count += 1
print(count)
# Out:
# 2
